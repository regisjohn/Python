# %% [markdown]
# # Run 20723 - 375 G guide field

# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
path_to_20723 = '/Users/emmanuelmacb/Library/CloudStorage/OneDrive-WestVirginiaUniversity/1 - Active Projects/1.01 - Fluid Simulations/1.01A - Fluid Project Updates/rundata/run207_23'
os.chdir(path_to_20723)

# %%
by_yt_xz0_20723 = np.load('by_yt_xz0_20723.npy')

# %%
whos
# Out:
# Variable          Type       Data/Info
# --------------------------------------
# by_yt_xz0_20723   ndarray    351x1024: 359424 elems, type `float64`, 2875392 bytes (2.7421875 Mb)
# os                module     <module 'os' (frozen)>
# path_to_20723     str        /Users/emmanuelmacb/Libra<...>Updates/rundata/run207_23

# %%
fig, ax = plt.subplots()
img = ax.pcolormesh(by_yt_xz0_20723)
cbar = fig.colorbar(img, ax=ax, format='%.1f')

# %%
fd
