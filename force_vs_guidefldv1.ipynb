# %% [markdown]
# # Reading data:

# %%
import os
import matplotlib.pyplot as plt

# %%
outdir = 'Combined_forceplots_v1'
w0 = 1.0
path_prefix = '/Users/emmanuelmacb/Library/CloudStorage/OneDrive-WestVirginiaUniversity/1 - Active Projects/1.01 - Fluid Simulations/1.01A - Fluid Project Updates/rundata/'
run_nos = ['25024','255','256','257','258']
final_path = [f'{path_prefix}/run{run_nos[i]}' for i in range(len(run_nos))]
fdat = []
for i in range(len(run_nos)):
    os.chdir(final_path[i])
    fdat.append(np.load(f'angular_force_dat_{run_nos[i]}.npz'))

# %% [markdown]
# # Extracting Data:

# %%
fdat_375 = fdat[0]
fdat_225 = fdat[1]
fdat_150 = fdat[2]
fdat_105 = fdat[3]
fdat_0 = fdat[4]

# %%
fdat_375.files
# Out:
# ['fx_min',
#  'fx_max',
#  'fz_min',
#  'fz_max',
#  'dfz_dfx',
#  'd_sep',
#  'rope_len',
#  'rhs_form']

# %%
fx_min_375 = fdat_375['fx_min']
fx_max_375 = fdat_375['fx_max']
fz_min_375 = fdat_375['fz_min']
fz_max_375 = fdat_375['fz_max']
d_sep_375 = fdat_375['d_sep']
rope_len_375 = fdat_375['rope_len']

# %%
fx_min_225 = fdat_225['fx_min']
fx_max_225 = fdat_225['fx_max']
fz_min_225 = fdat_225['fz_min']
fz_max_225 = fdat_225['fz_max']
d_sep_225 = fdat_225['d_sep']
rope_len_225 = fdat_225['rope_len']

# %%
fx_min_150 = fdat_150['fx_min']
fx_max_150 = fdat_150['fx_max'] 
fz_min_150 = fdat_150['fz_min']
fz_max_150 = fdat_150['fz_max']
d_sep_150 = fdat_150['d_sep']
rope_len_150 = fdat_150['rope_len']

# %%
fx_min_105 = fdat_105['fx_min']
fx_max_105 = fdat_105['fx_max']
fz_min_105 = fdat_105['fz_min']
fz_max_105 = fdat_105['fz_max']
d_sep_105 = fdat_105['d_sep']
rope_len_105 = fdat_105['rope_len']

# %%
fx_min_0 = fdat_0['fx_min']
fx_max_0 = fdat_0['fx_max']
fz_min_0 = fdat_0['fz_min']
fz_max_0 = fdat_0['fz_max']
d_sep_0 = fdat_0['d_sep']
rope_len_0 = fdat_0['rope_len']

# %%
os.chdir(final_path[0])

# %% [markdown]
# # Plotting fx vs rope length for different guide fields

# %%
fig, ax = plt.subplots(1,2, figsize=(16,6), dpi=100)

ax[0].scatter(rope_len_375, fx_max_375, color='black', marker='.', s=4, label='$fx_{max}$ 375G')
ax[0].scatter(rope_len_225, fx_max_225, color='green', marker='.', s=4, label='$fx_{max}$ 225G')
ax[0].scatter(rope_len_150, fx_max_150, color='blue', marker='.', s=4, label='$fx_{max}$ 150G')
ax[0].scatter(rope_len_105, fx_max_105, color='purple', marker='.', s=4, label='$fx_{max}$ 105G')
ax[0].scatter(rope_len_0, fx_max_0, color='red', marker='.', s=4, label='$fx_{max}$ 0G')
ax[0].set_xlabel('Rope Length', fontsize=14); ax[1].set_ylabel('$fx_{max}$', fontsize=14)
ax[0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=5)
ax[0].set_title('$fx_{max}$ vs Rope length for different guide fields', fontsize=16)

ax[1].scatter(rope_len_375, fx_min_375, color='black', marker='.', s=4, label='$fx_{min}$ 375G')
ax[1].scatter(rope_len_225, fx_min_225, color='green', marker='.', s=4, label='$fx_{min}$ 225G')
ax[1].scatter(rope_len_150, fx_min_150, color='blue', marker='.', s=4, label='$fx_{min}$ 150G')
ax[1].scatter(rope_len_105, fx_min_105, color='purple', marker='.', s=4, label='$fx_{min}$ 105G')
ax[1].scatter(rope_len_0, fx_min_0, color='red', marker='.', s=4, label='$fx_{min}$ 0G')
ax[1].set_xlabel('Rope Length', fontsize=14); ax[0].set_ylabel('$fx_min$', fontsize=14)
ax[1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=5)
ax[1].set_title('$fx_{min}$ vs Rope length for different guide fields', fontsize=16)

plt.tight_layout()

# Saving the plot
os.makedirs(outdir, exist_ok=True)
fig.savefig(f'{outdir}/fx_vs_guidefld.png', dpi=100, bbox_inches='tight')

# %% [markdown]
# # Plotting fz vs rope length for different guide fields

# %%
fig, ax = plt.subplots(1,2, figsize=(16,6), dpi=100)

ax[0].scatter(rope_len_375, fz_max_375, color='black', marker='.', s=4, label='$fz_{max}$ 375G')
ax[0].scatter(rope_len_225, fz_max_225, color='green', marker='.', s=4, label='$fz_{max}$ 225G')
ax[0].scatter(rope_len_150, fz_max_150, color='blue', marker='.', s=4, label='$fz_{max}$ 150G')
ax[0].scatter(rope_len_105, fz_max_105, color='purple', marker='.', s=4, label='$fz_{max}$ 105G')
ax[0].scatter(rope_len_0, fz_max_0, color='red', marker='.', s=4, label='$fz_{max}$ 0G')
ax[0].set_xlabel('Rope Length', fontsize=14); ax[1].set_ylabel('$fz_{max}$', fontsize=14)
ax[0].legend(loc='upper right')
ax[0].set_title('$fz_{max}$ vs Rope length for different guide fields', fontsize=16)

ax[1].scatter(rope_len_375, fz_min_375, color='black', marker='.', s=4, label='$fz_{min}$ 375G')
ax[1].scatter(rope_len_225, fz_min_225, color='green', marker='.', s=4, label='$fz_{min}$ 225G')
ax[1].scatter(rope_len_150, fz_min_150, color='blue', marker='.', s=4, label='$fz_{min}$ 150G')
ax[1].scatter(rope_len_105, fz_min_105, color='purple', marker='.', s=4, label='$fz_{min}$ 105G')
ax[1].scatter(rope_len_0, fz_min_0, color='red', marker='.', s=4, label='$fz_{min}$ 0G')
ax[1].set_xlabel('Rope Length', fontsize=14); ax[0].set_ylabel('$fz_min$', fontsize=14)
ax[1].legend(loc='upper right')
ax[1].set_title('$fz_{min}$ vs Rope length for different guide fields', fontsize=16)

plt.tight_layout()

# Saving the plot
os.makedirs(outdir, exist_ok=True)
fig.savefig(f'{outdir}/fz_vs_guidefld.png', dpi=100, bbox_inches='tight')

# %% [markdown]
# # Plotting force difference vs rope length for different guide fields

# %%
dfx_375 = fx_max_375 + fx_min_375
dfz_375 = np.abs(fz_max_375 + fz_min_375)

dfx_225 = fx_max_225 + fx_min_225
dfz_225 = np.abs(fz_max_225 + fz_min_225)

dfx_150 = fx_max_150 + fx_min_150
dfz_150 = np.abs(fz_max_150 + fz_min_150)

dfx_105 = fx_max_105 + fx_min_105
dfz_105 = np.abs(fz_max_105 + fz_min_105)

dfx_0 = fx_max_0 + fx_min_0
dfz_0 = np.abs(fz_max_0 + fz_min_0)

# %%
fig, ax = plt.subplots(1,2, figsize=(16,6), dpi=100)

ax[0].scatter(rope_len_375, dfx_375, color='black', marker='.', s=4, label='dfx 375G')
ax[0].scatter(rope_len_225, dfx_225, color='green', marker='.', s=4, label='dfx 225G')
ax[0].scatter(rope_len_150, dfx_150, color='blue', marker='.', s=4, label='dfx 150G')
ax[0].scatter(rope_len_105, dfx_105, color='purple', marker='.', s=4, label='dfx 105G')
ax[0].scatter(rope_len_0, dfx_0, color='red', marker='.', s=4, label='dfx 0G')
ax[0].set_xlabel('Rope Length', fontsize=14); ax[1].set_ylabel('dfx', fontsize=14)
ax[0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=5)
ax[0].set_title('$dfx$ vs Rope length for different guide fields', fontsize=16)

ax[1].scatter(rope_len_375, dfz_375, color='black', marker='.', s=4, label='dfz 375G')
ax[1].scatter(rope_len_225, dfz_225, color='green', marker='.', s=4, label='dfz 225G')
ax[1].scatter(rope_len_150, dfz_150, color='blue', marker='.', s=4, label='dfz 150G')
ax[1].scatter(rope_len_105, dfz_105, color='purple', marker='.', s=4, label='dfz 105G')
ax[1].scatter(rope_len_0, dfz_0, color='red', marker='.', s=4, label='dfz 0G')
ax[1].set_xlabel('Rope Length', fontsize=14); ax[0].set_ylabel('dfz', fontsize=14)
ax[1].legend(loc='lower right')
ax[1].set_title('$dfz$ vs Rope length for different guide fields', fontsize=16)

plt.tight_layout()

# Saving the plot
os.makedirs(outdir, exist_ok=True)
fig.savefig(f'{outdir}/df_vs_guidefld.png', dpi=100, bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6), dpi=100)
ax.scatter(rope_len_375, dfx_375, color='black', marker='.', s=4, label='dfx 375G')
ax.set_xlabel('Rope Length', fontsize=14); ax.set_ylabel('dfx', fontsize=14)
ax.legend(loc='upper right')
ax.set_title('$dfx$ vs Rope length for 375G', fontsize=16)

plt.tight_layout()

# Saving the plot
os.makedirs(outdir, exist_ok=True)
fig.savefig(f'{outdir}/dfx_vs_ropelen_375G.png', dpi=100, bbox_inches='tight')

# %%
fig, ax = plt.subplots(1,1, figsize=(8,6), dpi=100)
ax.scatter(rope_len_225, dfx_225, color='black', marker='.', s=4, label='dfx 375G')
ax.set_xlabel('Rope Length', fontsize=14); ax.set_ylabel('dfx', fontsize=14)
ax.legend(loc='upper right')
ax.set_title('$dfx$ vs Rope length for 225G', fontsize=16)

plt.tight_layout()

# Saving the plot
os.makedirs(outdir, exist_ok=True)
fig.savefig(f'{outdir}/dfx_vs_ropelen_225G.png', dpi=100, bbox_inches='tight')

# %% [markdown]
# # Plotting dfx/dfz vs rope length for different guide fields

# %%
dfx_dfz_375 = dfx_375/dfz_375; dfz_dfx_375 = dfz_375/dfx_375
dfx_dfz_225 = dfx_225/dfz_225; dfz_dfx_225 = dfz_225/dfx_225
dfx_dfz_150 = dfx_150/dfz_150; dfz_dfx_150 = dfz_150/dfx_150
dfx_dfz_105 = dfx_105/dfz_105; dfz_dfx_105 = dfz_105/dfx_105
dfx_dfz_0 = dfx_0/dfz_0; dfz_dfx_0 = dfz_0/dfx_0
# Out:
# /var/folders/gz/3q9vwygx1pz7yz2y5rp5dd1m0000gn/T/ipykernel_7111/3529555183.py:5: RuntimeWarning: divide by zero encountered in divide
#   dfx_dfz_0 = dfx_0/dfz_0; dfz_dfx_0 = dfz_0/dfx_0

# %%
fig, ax = plt.subplots(1,2, figsize=(16,6), dpi=100)

ax[0].scatter(rope_len_375, dfz_dfx_375, color='black', marker='.', s=4, label='dfz/dfx 375G')
ax[0].scatter(rope_len_225, dfz_dfx_225, color='green', marker='.', s=4, label='dfz/dfx 225G')
ax[0].scatter(rope_len_150, dfz_dfx_150, color='blue', marker='.', s=4, label='dfz/dfx 150G')
ax[0].scatter(rope_len_105, dfz_dfx_105, color='purple', marker='.', s=4, label='dfz/dfx 105G')
ax[0].set_xlabel('Rope Length', fontsize=14); ax[0].set_ylabel('dfz/dfx', fontsize=14)
ax[0].legend(loc='upper left', fontsize=12)
ax[0].set_title('$dfz/dfx$ vs Rope length for different guide fields', fontsize=16)

ax[1].scatter(rope_len_375, dfx_dfz_375, color='black', marker='.', s=4, label='dfx_dfz 375G')
ax[1].scatter(rope_len_225, dfx_dfz_225, color='green', marker='.', s=4, label='dfx_dfz 225G')
ax[1].scatter(rope_len_150, dfx_dfz_150, color='blue', marker='.', s=4, label='dfx_dfz 150G')
ax[1].scatter(rope_len_105, dfx_dfz_105, color='purple', marker='.', s=4, label='dfx_dfz 105G')
ax[1].scatter(rope_len_0, dfx_dfz_0, color='red', marker='.', s=4, label='dfx_dfz 0G')
ax[1].set_xlabel('Rope Length', fontsize=14); ax[1].set_ylabel('dfx/dfz', fontsize=14)
ax[1].legend(loc='upper right', fontsize=12)
ax[1].set_title('$dfx/dfz$ vs Rope length for different guide fields', fontsize=16)

plt.tight_layout()

# Saving the plot
os.makedirs(outdir, exist_ok=True)
fig.savefig(f'{outdir}/df_ratio_vs_guidefld.png', dpi=100, bbox_inches='tight')

# %% [markdown]
# # Plotting approach angle vs rope length for different guide fields

# %%
app_angle_375 = np.degrees(np.arctan2(dfx_375, dfz_375))
app_angle_225 = np.degrees(np.arctan2(dfx_225, dfz_225))
app_angle_150 = np.degrees(np.arctan2(dfx_150, dfz_150))
app_angle_105 = np.degrees(np.arctan2(dfx_105, dfz_105))
app_angle_0 = np.degrees(np.arctan2(dfx_0, dfz_0))

# %%
fig, ax = plt.subplots(1,1, figsize=(16,6), dpi=100)

ax.scatter(rope_len_375, app_angle_375, color='black', marker='.', s=4, label='Approach Angle 375G')
ax.scatter(rope_len_225, app_angle_225, color='green', marker='.', s=4, label='Approach Angle 225G')
ax.scatter(rope_len_150, app_angle_150, color='blue', marker='.', s=4, label='Approach Angle 150G')
ax.scatter(rope_len_105, app_angle_105, color='purple', marker='.', s=4, label='Approach Angle 105G')
ax.scatter(rope_len_0, app_angle_0, color='red', marker='.', s=4, label='Approach Angle 0G')
ax.set_xlabel('Rope Length', fontsize=14); ax.set_ylabel('Angle (deg)', fontsize=14)
ax.legend(loc='upper right', fontsize=10)
ax.set_title('Approach Angle vs Rope length for different guide fields', fontsize=16)

plt.tight_layout()

# Saving the plot
os.makedirs(outdir, exist_ok=True)
fig.savefig(f'{outdir}/app_angle_vs_guidefld.png', dpi=100, bbox_inches='tight')
